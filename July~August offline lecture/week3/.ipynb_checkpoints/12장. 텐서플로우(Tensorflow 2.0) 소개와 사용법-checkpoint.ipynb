# %%
import tensorflow as tf

a=tf.constant(10)
b=tf.constant(32)
sess = tf.Session()
print (sess.run(a+b))
# Out:
# 42

# %%
##텐서플로우 처리 순서
x = tf.constant(35, name='x')
y = tf.Variable(x+5,name='y')
model =  tf.global_variables_initializer()
with tf.Session() as session:
    session.run(model)
    print(session.run(y))
# Out:
# 40

# %%
## XOR 문제

T = 1.
F = 0.
train_in = [
    [T, T],
    [T, F],
    [F, T],
    [F, F],
]
train_out = [
    [F],
    [T],
    [T],
    [F],
]
w1 = tf.Variable(tf.random_normal([2, 2]))
b1 = tf.Variable(tf.zeros([2]))

w2 = tf.Variable(tf.random_normal([2, 1]))
b2 = tf.Variable(tf.zeros([1]))

out1 = tf.nn.relu(tf.matmul(train_in, w1) + b1)
out2 = tf.nn.relu(tf.matmul(out1, w2) + b2)

error = tf.subtract(train_out, out2)
mse = tf.reduce_mean(tf.square(error))

err = 1.0
target = 0.01
epoch = 0
max_epochs = 1000

train = tf.train.GradientDescentOptimizer(0.01).minimize(mse)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

while err > target and epoch < max_epochs:
    epoch += 1
    err, _ = sess.run([mse, train])

print("epoch:", epoch, "mse:", err)
print("result: ", out1)
# Out:
# epoch: 1000 mse: 0.5
# result:  Tensor("Relu:0", shape=(4, 2), dtype=float32)

# %%
##Eager Execution (기능확인)
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf
tf.enable_eager_execution() 
print(tf.executing_eagerly())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-a5c8cf028c24> in <module>()
#       2 from __future__ import absolute_import, division, print_function, unicode_literals
#       3 import tensorflow as tf
# ----> 4 tf.enable_eager_execution()
#       5 print(tf.executing_eagerly())
#
# AttributeError: module 'tensorflow' has no attribute 'enable_eager_execution'

# %%
## Eager Execution (실행)
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf
tf.enable_eager_execution()


x = tf.matmul([[1,2],[3,4]],[[4,5],[6,7]])
y = tf.add(x, 1)
z = tf.random_uniform([5, 3])

print(x)
print(y)
print(z)

# %%
# Eager Execution (NumPy)

import numpy as np
import tensorflow as tf
tf.enable_eager_execution() 


x = tf.add(1, 1)                     # tf.Tensor with a value of 2
y = tf.add(np.array(1), np.array(1)) # tf.Tensor with a value of 2
z = np.multiply(x, y)                # numpy.int64 with a value of 4

print(y)
print(y.numpy())
# Out:
# Tensor("Add_1:0", shape=(), dtype=int32)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-8439ed1fa1c5> in <module>()
#       9
#      10 print(y)
# ---> 11 print(y.numpy())
#
# AttributeError: 'Tensor' object has no attribute 'numpy'

# %%
#Fizzbuzz
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

def fizzbuzz(max_num):
    counter = tf.constant(0)
    max_num = tf.convert_to_tensor(max_num)
    for num in range(1, max_num.numpy()+1):
        num = tf.constant(num)
        if int(num % 3) == 0 and int(num % 5) == 0:       print('FizzBuzz')
        elif int(num % 3) == 0:       			       print('Fizz')
        elif int(num % 5) == 0:       		 	       print('Buzz')
        else:       					       print(num.numpy())
        counter += 1

fizzbuzz(10)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-5c7c7af6fca5> in <module>()
#       2 import numpy as np
#       3 import tensorflow as tf
# ----> 4 from tensorflow.keras import layers
#       5
#       6 def fizzbuzz(max_num):
#
# ModuleNotFoundError: No module named 'tensorflow.keras'

# %%
#XOR 문제 (TF 2.0)
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

training_data = np.array([[0,0],[0,1],[1,0],[1,1]], "float32")
target_data = np.array([[0],[1],[1],[0]], "float32")

model = tf.keras.Sequential()
model.add(layers.Dense(16, input_dim=2, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(loss='mse',  optimizer='adam',  metrics=['binary_accuracy'])
model.fit(training_data, target_data, nb_epoch=20)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-4bc9106c47c5> in <module>()
#       2 import numpy as np
#       3 import tensorflow as tf
# ----> 4 from tensorflow.keras import layers
#       5
#       6 training_data = np.array([[0,0],[0,1],[1,0],[1,1]], "float32")
#
# ModuleNotFoundError: No module named 'tensorflow.keras'

# %% [markdown]
# # Tensorflow 개요
# ### Tensorflow
# 텐서플로우는 데이터 플로우 그래프를 사용하여 수치 연산을 하는 오픈소스 소프트웨어 라이브러리입니다.
#
# CPU나 GPU를 사용하여 연산을 구동시킬수 있으며 머신러닝과 딥러닝 연구를 목적으로 구글 브레인 팀에 의해 개발되었습니다.
#
# ### Eager Excution
# 기존 텐서플로우 1.x 버전에서는 그래프 구조로 만들어져 연산이 되도록 구성되어 있습니다. 그래프 구조에 대해서는 실습 7-5에서 다루겠습니다.
#
# 그러나 텐서플로우 2.0에서는 파이썬의 함수처럼 바로바로 계산되어 사용할 수 있습니다. 이를 즉시 실행 (Eager Excution) 모드라고 합니다.
#
# ### 실습
# 작성된 코드를 보며 Tensorflow가 어떻게 구성되어 있는지 이해해보세요.

# %%
import tensorflow as tf

# 즉시 실행 모드가 설정되어 있다면 True를 반환해줍니다.
print(tf.executing_eagerly())

# Tensorflow 상수 선언
a = tf.constant(5, name = 'input_node1')
b = tf.constant(3, name = 'input_node2')

# Tensorflow 연산 Node
c = tf.add(a,b, name = 'add_c')
d = tf.subtract(a,b, name = 'sub_d')
e = tf.multiply(c,d, name = 'add_e')

# Tensorflow 문자열 선언
hello = tf.constant('hello Tensorflow!')

# 선언한 변수들을 출력해보면 결과값이 아닌 데이터의 타입이나 형태가 출력됩니다.
for i in [a,b,c,d,e, hello]:
    print(i)
print('--------------------')
# 실제로 데이터의 값을 출력하기 위해서 numpy()를 사용합니다.
for i in [a,b,c,d,e, hello]:
    print(i.numpy())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-1176feba841a> in <module>()
#       2
#       3 # 즉시 실행 모드가 설정되어 있다면 True를 반환해줍니다.
# ----> 4 print(tf.executing_eagerly())
#       5
#       6 # Tensorflow 상수 선언
#
# AttributeError: module 'tensorflow' has no attribute 'executing_eagerly'

# %% [markdown]
# # Tensor 데이터 생성
# 텐서플로우는 상수, 시퀀스, 난수, 변수 등을 생성하는 연산을 제공합니다. 기존 Numpy와 유사하게 사용할 수 있습니다.
#
# ## 상수
# * tf.constant(value, dtype=None, shape=None, name='Const')
#
#     * value : 반환되는 상수값
#     * 1shape : Tesnor의 차원
#     * dtype : 반환되는 Tensor 타입
#     * name : 상수 이름
# * tf.zeros(shape, dtype=tf.float32, name=None) : 모든 원소 값이 0인 Tensor 생성
#
# * tf.ones(shape, dtype=tf.float32, name=None) : 모든 원소 값이 1인 Tensor 생성
#
# * tf.fill(dims, value, name=None) : value로 채워진 Tensor 생성
#
#     * dims : 반환되는 Tensor의 차원
#
# ### 시퀀스
# * tf.linspace(start, stop, num, name=None)
#
#     * start : 시작 값
#     * stop : 끝 값
#     * num : 생성할 데이터 개수
#     * {stop - start \over num - 1}
#     * stop−start / num−1 씩 증가
#
# * tf.range(start, limit=None, delta=1, name='range')
#
#     * start : 시작 값
#     * limit : 끝 값
#     * delta : 증가량
#
# ### 난수
# * tf.compat.v1.set_random_seed(seed) : 난수 시드 설정
#
# * tf.random.normal(shape, mean=0.0, stddev=1.0, dtype=tf.float32, seed=None, name=None) : 정규분포로 부터 난수 생성
#
# * tf.random.uniform(shape, minval=0, maxval=None, dtype=tf.float32, seed=None, name=None) : 균등분포로 부터 난수 생성
#
# ### 변수
# 기존의 Tensor와 Operation 객체는 변경할 수 없습니다. 그러므로 연산에 따라 변경되는 값을 저장할 변수가 필요합니다.
#
# * tf.Variable(value, name) : 변수 생성
#
# ### 실습
# 주석을 보고 빈 부분을 알맞게 작성해보세요.

# %%
import numpy as np
import tensorflow as tf

print(tf.__version__)
# tf.constant로 상수를 생성해보세요.
a =tf.constant(5, dtype=None, shape=None, name='Const')

# tf.zeros, tf.one, tf.fill을 사용해 Shape을 가진 텐서를 생성해보세요.
b = tf.zeros([2,2], dtype=tf.float32, name=None)
c = tf.ones([2,3], dtype=tf.float32, name=None)
d = tf.fill([3,2], 4, name=None)

# tf.linspace, tf.range로 시퀀스 텐서를 생성해보세요.
lin = tf.linspace(0.0, 10.0, 20, name='lins')
ran = tf.range(1, 6, delta=1, name='range')

# 난수 시드 설정해보세요.
seed = tf.compat.v1.set_random_seed(123)

# 정규 분포를 가진 난수 텐서를 생성해보세요.
norm_dist = tf.random.normal([4,4], mean=0.0, stddev=1.0, dtype=tf.float32, seed=None, name=None)
# 균등 분포를 가진 난수 텐서를 생성해보세요.
uni_dist = tf.random.uniform([4,5], minval=0, maxval=None, dtype=tf.float32, seed=None, name=None)

# tf.Variable을 생성해보세요.
# 딥러닝 모델을 학습할 때 사용되는 weight와 bias는 variable로 생성합니다.
weight = tf.Variable(6, name ='weight')
bias = tf.Variable(7, name='bias')

# 각 상수, 시퀀스, 난수, 변수 출력
for i in [a, b, c, d, lin, ran, norm_dist, uni_dist, weight, bias]:
    print(i.numpy())
# Out:
# 1.5.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-6245e90b2a32> in <module>()
#      16
#      17 # 난수 시드 설정해보세요.
# ---> 18 seed = tf.compat.v1.set_random_seed(123)
#      19
#      20 # 정규 분포를 가진 난수 텐서를 생성해보세요.
#
# AttributeError: module 'tensorflow.python.util.compat' has no attribute 'v1'

# %% [markdown]
# # Tensor 데이터 타입 및 연산
# ### Data type
# Tensorflow에서는 다양한 자료형을 사용할 수 있습니다. 이를 이용하면 어떤 데이터든지 구조화된 형식으로 저장할 수 있습니다.
#
#     * tf.float32 : 32-bit float
#     * tf.float64 : 64-bit float
#     * tf.int8 : 8-bit integer
#     * tf.int16 : 16-bit integer
#     * tf.int32 : 32-bit integer
#     * tf.uint8 : 8-bit unsigned integer
#     * tf.string : String
#     * tf.bool : Boolean
#
#    ----------------------------
#
# ### 연산자
# Tensorflow에도 Numpy와 유사하게 다양한 수학 연산자들을 제공합니다.
#
# --------------------------
#
# ### 단항 연산자
#
#     * tf.negative(x) = -x
#     * tf.logical_not(x) = !x (tf.bool만 가능)
#     * tf.abs(x) = x의 절대값
#
# ### 이항 연산자
#
#     * tf.add() : x + y
#     * tf.subtract() : x - y
#     * tf.multiply() : x * y
#     * tf.divide() : x / y (Python 2)
#     * tf.truediv() : x / y (Python 3)
#     * tf.math.floordiv() : x // y
#     * tf.math.mod() : x % y
#     * tf.math.pow()	: x ** y
#
# ### 실습
# 주석을 보고 알맞게 빈 부분을 채워보세요.

# %%
import tensorflow as tf


# 다양한 형태의 데이터 타입으로 상수를 선언해보세요.
#tf.constant(value, dtype=None, shape=None, name='Const')
a =  tf.constant(4, dtype=tf.float32, shape=None, name='f32')    # Int or float
b = tf.constant(7, dtype=tf.float32)     # Int or float
c = tf.constant(-5, dtype=tf.int32) # Negative int
string1 =tf.constant('abc', dtype=tf.string, shape=None, name='ST1')   # String
string2 = tf.constant('def', dtype=tf.string, shape=None, name='ST2')  # String
boolean = tf.constant(True, dtype=tf.bool, shape=None, name='Bool')  # Boolean

# 단항 연산자를 사용해보세요.
neg = tf.negative(a)   # Negative
logic = tf.logical_not(boolean) # Logical negative
absolute = tf.abs(c)      # Absolute

# 사칙연산을 수행해보세요.
add = tf.add(b,a)      # add
sub = tf.subtract(a,b)      # subtract
mul = tf.multiply(b,a)      # multiply
div = tf.truediv(a,b)      # divide   tf.divide() in python 2.x
                        #tf.math.floordiv()  : x // y

mod = tf.math.mod(b,a)      # Modulo
po = tf.math.pow(b,a)       # Pow

for i in [a,b,c,string1,string2,boolean,neg,logic,absolute,add,  sub, mul, div, mod, po]:
    print(i.numpy())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-fed91e49e3ad> in <module>()
#      23                         #tf.math.floordiv()  : x // y
#      24
# ---> 25 mod = tf.math.mod(b,a)      # Modulo
#      26 po = tf.math.pow(b,a)       # Pow
#      27
#
# AttributeError: module 'tensorflow' has no attribute 'math'

# %% [markdown]
# # Tensorflow 선형 회귀
# Tensorflow에서 어떻게 머신러닝, 딥러닝 네트워크가 학습이 되는지 전체적인 실습 코드를 통해 배워보겠습니다.
#
# 앞으로 배울 MLP, CNN, RNN 등 다양한 네트워크가 실습 코드와 같은 형식으로 작성됩니다.
#
# 코드가 눈에 익숙해지도록 전체적인 흐름을 이해해보세요.
#
# ### 선형 회귀
# 선형 회귀는 존재하는 데이터를 이용해 데이터의 분포를 잘 나타내는 선을 찾는 문제입니다.
#
# * x_data = [1,2,3,4,5]
# * y_data = [1,2,3,4,5]
#
# 현재 데이터를 가장 잘 나타내는 선은 y = x입니다.
#
# 데이터를 잘 나타내는 선을 찾는 과정에서 W(weight)값과 b(bias)값을 Gradient Descent 알고리즘을 이용해 찾는 과정을 보여줍니다.
#
# 자세한 이론 및 실습은 추후 강의에서 다루겠습니다. 우선 전체적인 형태를 익혀보세요.
#
# W와 b 값이 처음에 랜덤으로 주어진 상태에서 점차 W는 1에 b는 0에 가까워지는 것을 볼 수 있습니다. (cost function의 값도 줄어드는 것을 확인할 수 있습니다.)
#
# ### 실습
# 랜덤하게 설정된 텐서플로우 변수 W와 b의 값이 어떻게 변하는지 확인해보세요.
#
# train_step을 바꿔가며 W,b값을 확인해보세요. train_step이 너무 적거나 많으면 학습이 잘 진행되지 않을 수 있습니다.
#
# learning_rate의 수치를 변경해 보세요. learning_rate의 값이 커질수록 빨리 수렴하고 작아질수록 천천히 수렴하는 것을 볼 수 있습니다.
#
# {0.01 < learning_rate <= 0.1}

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

def Visualize(x_data, y_data, hypothesis):
    fig, ax = plt.subplots()
    ax.grid()
    ax.plot(x_data, hypothesis.numpy(), 'r-')
    ax.plot(x_data, y_data, 'o')
#     fig.savefig("plot.png")

# Hyperparameter 설정
# 학습에 필요한 파라미터를 선언합니다.
train_step = 500
learning_rate = 0.07

# 학습에 사용할 데이터를 준비합니다.
x_data = [1, 2, 3, 4, 5]
y_data = [1, 2, 3, 4, 5]

# 학습에 사용될 Weight와 Bias를 선언합니다.
# 일반적으로 랜덤 값으로 선언해 사용하며 학습 데이터와 Shape을 일치시킵니다.
W = tf.Variable((-5.0), dtype=tf.float32)
b = tf.Variable((2.0), dtype=tf.float32)


# 학습을 진행합니다.
for i in range(train_step):
    with tf.GradientTape() as tape:
        # y = W*X + b 형태의 hypothesis를 선언합니다.
        hypothesis = tf.add(W * x_data, b)
        # 에러를 최소화시키는 손실 함수 cost function을 설계합니다.
        cost = tf.reduce_mean(tf.square(hypothesis - y_data))
    
    # Gradient Descent 방법으로 Error를 최소화하고 Weight와 Bias를 업데이트 합니다.
    W_grad, b_grad = tape.gradient(cost, [W, b])
    W.assign_sub(learning_rate * W_grad)
    b.assign_sub(learning_rate * b_grad)
    
    # 30번 마다 출력
    if i % 30 == 0:
        Visualize(x_data,y_data,hypothesis)        
        print("Iter : {}| Weight : {:.4f}| Bias : {:.4f}|Cost : {:.4f}".format(i, W.numpy(), b.numpy(), cost))

# 학습된 Weight와 Bias로 검증
print((W * 5.5 + b).numpy())
print((W * 3 + b).numpy())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-335719af7613> in <module>()
#      27 # 학습을 진행합니다.
#      28 for i in range(train_step):
# ---> 29     with tf.GradientTape() as tape:
#      30         # y = W*X + b 형태의 hypothesis를 선언합니다.
#      31         hypothesis = tf.add(W * x_data, b)
#
# AttributeError: module 'tensorflow' has no attribute 'GradientTape'

# %% [markdown]
# # Tensorflow Session
# ## Tensorflow 1.x
# 텐서플로우 2.0이 가장 최근에 만들어졌지만 beta version이기 때문에 아직 1.x 버전을 사용하는 경우가 많습니다.
#
# 기존 텐서플로우 1.x 버전에서는 계산 그래프 구조를 가지고 있으며 각 노드별 출력 결과를 전달하는 함수들이 연속적으로 연결된 형태를 가지고 있습니다.
#
# https://kasausyrzlhe1066469.cdn.ntruss.com/global/file/p/5d12d95a28a2efd1bb620455/tensorflow.jpeg
# Tensorflow 1.x 그래프 구조
#
# 이번 실습에서는 텐서플로우2.0과 1.x의 차이를 알아보겠습니다. 실습 7-4와 같은 선형 회귀 예제를 1.x버전으로 진행해보겠습니다.
#
# ### Session
# tf.Session()은 상수, 변수, 오퍼레이션을 선언하고 실질적으로 그래프를 실행하기 위한 객체입니다.
#
# 2.0 버전에서는 즉시 실행(Eager Excution)을 지원하지만 1.x 버전에서는 Session에서 모든 학습과 계산을 진행합니다.
#
# 값을 계산하고 출력하기 위해서는 Session()을 반드시 실행시켜야합니다.
#
# -------------
# * sess = tf.Session()
# * sess.run(fetches, feed_dict)
#     * fetches : 실행시키고자 하는 그래프 구성 요소
#     * feed_dict : dictionary 객체 입력
# * sess.run(tf.initializers.global_variables()) : 변수 초기화
# * sess.close() : 연산이 끝났으면 Session을 닫아줍니다.
# * feed_dict
# * feed_dict는 그래프에서 Tensor의 값을 오버라이드 할 때 사용되며 Dictionary 객체를 받아 입력으로 사용합니다.
#
# ---------------------
# 입력 받는 값들은 숫자, 문자열, Numpy 배열 등 다양한 형태가 될 수 있으며 Tensor와 같은 자료형이여야 합니다.
#
# * feed_dict = {X : data}
#
# ### Placeholder
# tf.placeholder()는 생성될 때 값을 가지지는 않지만 입력될 자리를 만들어놓습니다. 간단히 말해 Input Node가 됩니다.
#
# 상수나 난수 같은 고정된 값이 아닌 사용자로부터 입력을 받아야할 때 사용됩니다. 이를 위해 tf.placeholder()를 사용합니다.
#
# * tf.placeholder(dtype, shape, name)
#
# ### 실습
# 작성된 코드를 보고 따라가며 이해해보세요.
#
# tf.placeholder()를 선언하여 입력 노드를 생성합니다.
#
# tf.Session()을 열어 Session 내에서 연산이 수행되도록 합니다. Session을 실행하기전 변수를 초기화 해주어야합니다.
#
# 상수, 변수, 객체 등 연산을 실질적으로 수행하는 sess.run()을 사용하여 연산을 수행합니다.
#
# feed_dict에 데이터를 입력하여 기존 선언한 데이터나 사용자가 직접 데이터를 입력할 수 있도록 되어있습니다.
#
# 2.0 버전과 1.x 버전의 차이를 기억하세요.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# Tensorflow 1.8 Version
print(tf.__version__)

# 시각화 함수
def Visualize(x_data, y_data, hypothesis):
    fig, ax = plt.subplots()
    ax.grid()
    ax.plot(x_data, hypothesis, 'r-')
    ax.plot(x_data, y_data, 'o')
#     fig.savefig("plot.png")

# 선형 데이터 x, y 선언
x_data = [1, 2, 3, 4, 5]
y_data = [1, 2, 3, 4, 5]

# 학습에 사용할 Weight, Bias 선언
W = tf.Variable(tf.random_uniform([1], -5.0, 5.0))
b = tf.Variable(tf.random_uniform([1], -5.0, 5.0))

# 입력이 들어갈 Placeholder (Input Node) 선언
X = tf.placeholder(tf.float32)
Y = tf.placeholder(tf.float32)

# Cost 함수 설계
hypothesis = W * X + b
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# 학습 속도, Cost (Loss)를 줄여나가는 방법을 정하고 Optimizer를 선언합니다.
learning_rate = 0.01
optimizer = tf.train.GradientDescentOptimizer(learning_rate)
train = optimizer.minimize(cost)

# Session을 열어줍니다.
sess = tf.Session()

# Session 내의 전체 변수를 초기화
sess.run(tf.initializers.global_variables())

# 200번 학습 진행
for i in range(200):
    # Train 객체에 학습 데이터 x_data와 Label 값 y_data를 입력합니다.
    # 입력은 feed_dict로 딕셔너리 형태의 입력이 들어갑니다.
    sess.run(train, feed_dict={X: x_data, Y: y_data})
    if i % 30 == 0:
        Visualize(x_data, y_data, sess.run(hypothesis, feed_dict = {X : x_data}))
        print("Step : {}| Weight : {:.5f}| Bias : {:.5f}| Cost : {:.5f}".format(i,float(sess.run(W)), float(sess.run(b)), float(sess.run(cost, feed_dict={X: x_data, Y: y_data}))))

# Iteration이 끝나면 학습이 끝났습니다.        
# 이제 검증 데이터로 학습된 hypothesis 성능을 평가합니다.
print(sess.run(hypothesis, feed_dict = {X : 5}))
print(sess.run(hypothesis, feed_dict = {X : 2.5}))

# 연산이 전부 끝났으면 Session을 닫아줍니다.
sess.close()
# Out:
# 1.5.0
# Step : 0| Weight : 0.70308| Bias : 2.43945| Cost : 2.57476
# Step : 30| Weight : 0.41408| Bias : 2.11578| Cost : 0.81478
# Step : 60| Weight : 0.47059| Bias : 1.91135| Cost : 0.66496
# Step : 90| Weight : 0.52173| Bias : 1.72669| Cost : 0.54268
# Step : 120| Weight : 0.56794| Bias : 1.55988| Cost : 0.44289
# Step : 150| Weight : 0.60968| Bias : 1.40918| Cost : 0.36145
# Step : 180| Weight : 0.64739| Bias : 1.27304| Cost : 0.29498
# [4.54052]
# [2.8671112]

# %% [markdown]
# # Tensorflow + Keras
# ## Keras
# 케라스 (Keras)는 Sequential하게 계층 (Layer)들을 쌓아가며 모델을 생성하고 사이킷런과 같이 한 줄의 코드로 간단하게 학습 방법 설정, 학습, 평가를 진행할 수 있는 API입니다.
#
# * keras.Sequential() : Sequential 모델을 만들기 위한 함수
# * keras.layers() : Fully connected, Convolution 등 다양한 Layer 제공
# * model.complie : 학습 방법 설정
# * model.summary() : 모델 출력
# * model.fit() : 모델 학습
#
# 관련 링크
#
# https://www.tensorflow.org/beta/guide/keras/overview?hl=ko
#
# ### 실습
# 작성된 코드를 보고 이해해보세요.
#
# keras.layers.Dense()의 뉴런 개수, Activation, layer 개수를 바꿔가며 결과를 분석해보세요.
#
# model.fit()의 학습 횟수 (Epoch)를 바꿔가며 결과를 확인해보세요.
#
# Tip 앞으로 실습에서 간단하게 딥러닝을 구현할 수 있는 Keras를 주로 다룰 예정입니다.
#
# 좀 더 심화 과정(모델 파라미터 직접 설정 및 세부 설계)을 원하신다면
#
# https://www.tensorflow.org/beta/tutorials/quickstart/advanced?hl=ko
# 위의 링크를 참고하여 공부해보세요!

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras

# 임의의 데이터 x, y를 선언합니다.
x = np.random.rand(100,1)
y = 5 * x + 3 * np.random.rand(1)

# Keras는 Sequential하게 모델을 선언합니다.
# Sequential.add 방법으로 모델을 만들 수도 있고
# 아래와 같이 Sequential의 내부 인자로 Layer를 쌓을 수도 있습니다.
model = keras.Sequential([
    # `.summary` 메서드 때문에 `input_shape`가 필요합니다
    # 첫 번째 Layer에 데이터를 넣을때는 input_shape을 맞춰줘야합니다.
    keras.layers.Dense(32, activation=tf.nn.relu, input_shape = (1, )),
    keras.layers.Dense(32, activation=tf.nn.relu),
    keras.layers.Dense(1)
])

# 모델을 학습시킬 최적화 방법, loss 계산 방법, 평가 방법을 설정합니다.
model.compile(optimizer='adam',loss='mse',metrics=['mse', 'binary_crossentropy'])
# 모델이 어떻게 이루어져있는지 출력합니다.
model.summary()
# 모델을 학습시킵니다
history = model.fit(x,y, epochs = 300, batch_size = 100 )

# 결과 출력
plt.scatter(x, y, label='y_true')
plt.scatter(x, model.predict(x), label='y_pred')
plt.legend()
# plt.savefig("plot.png")
# Out:
# WARNING:tensorflow:From C:\Users\user\Anaconda3\lib\site-packages\tensorflow\python\keras\_impl\keras\backend.py:1557: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 32)                64
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 1,153
# Trainable params: 1,153
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 100/100 [==============================]100/100 [==============================] - 1s 8ms/step - loss: 9.2533 - mean_squared_error: 9.2533 - binary_crossentropy: 10.3099
#
# Epoch 2/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 9.1275 - mean_squared_error: 9.1275 - binary_crossentropy: 8.2994
#
# Epoch 3/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 9.0021 - mean_squared_error: 9.0021 - binary_crossentropy: 7.1379
#
# Epoch 4/300
# 100/100 [==============================]100/100 [==============================] - 0s 70us/step - loss: 8.8779 - mean_squared_error: 8.8779 - binary_crossentropy: 6.3058
#
# Epoch 5/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 8.7553 - mean_squared_error: 8.7553 - binary_crossentropy: 5.6524
#
# Epoch 6/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 8.6333 - mean_squared_error: 8.6333 - binary_crossentropy: 5.1072
#
# Epoch 7/300
# 100/100 [==============================]100/100 [==============================] - 0s 80us/step - loss: 8.5115 - mean_squared_error: 8.5115 - binary_crossentropy: 4.6337
#
# Epoch 8/300
# 100/100 [==============================]100/100 [==============================] - 0s 51us/step - loss: 8.3894 - mean_squared_error: 8.3894 - binary_crossentropy: 4.2108
#
# Epoch 9/300
# 100/100 [==============================]100/100 [==============================] - 0s 60us/step - loss: 8.2662 - mean_squared_error: 8.2662 - binary_crossentropy: 3.8239
#
# Epoch 10/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 8.1398 - mean_squared_error: 8.1398 - binary_crossentropy: 3.4600
#
# Epoch 11/300
# 100/100 [==============================]100/100 [==============================] - 0s 80us/step - loss: 8.0122 - mean_squared_error: 8.0122 - binary_crossentropy: 3.1187
#
# Epoch 12/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 7.8841 - mean_squared_error: 7.8841 - binary_crossentropy: 2.7963
#
# Epoch 13/300
# 100/100 [==============================]100/100 [==============================] - 0s 70us/step - loss: 7.7557 - mean_squared_error: 7.7557 - binary_crossentropy: 2.4891
#
# Epoch 14/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 7.6270 - mean_squared_error: 7.6270 - binary_crossentropy: 2.1939
#
# Epoch 15/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 7.4982 - mean_squared_error: 7.4982 - binary_crossentropy: 1.9084
#
# Epoch 16/300
# 100/100 [==============================]100/100 [==============================] - 0s 60us/step - loss: 7.3695 - mean_squared_error: 7.3695 - binary_crossentropy: 1.6303
#
# Epoch 17/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 7.2409 - mean_squared_error: 7.2409 - binary_crossentropy: 1.3574
#
# Epoch 18/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 7.1118 - mean_squared_error: 7.1118 - binary_crossentropy: 1.0865
#
# Epoch 19/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 6.9818 - mean_squared_error: 6.9818 - binary_crossentropy: 0.8142
#
# Epoch 20/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 6.8518 - mean_squared_error: 6.8518 - binary_crossentropy: 0.5401
#
# Epoch 21/300
# 100/100 [==============================]100/100 [==============================] - 0s 60us/step - loss: 6.7223 - mean_squared_error: 6.7223 - binary_crossentropy: 0.2624
#
# Epoch 22/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 6.5937 - mean_squared_error: 6.5937 - binary_crossentropy: -0.0215
#
# Epoch 23/300
# 100/100 [==============================]100/100 [==============================] - 0s 80us/step - loss: 6.4667 - mean_squared_error: 6.4667 - binary_crossentropy: -0.3136
#
# Epoch 24/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 6.3421 - mean_squared_error: 6.3421 - binary_crossentropy: -0.6163
#
# Epoch 25/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 6.2184 - mean_squared_error: 6.2184 - binary_crossentropy: -0.9409
#
# Epoch 26/300
# 100/100 [==============================]100/100 [==============================] - 0s 60us/step - loss: 6.0954 - mean_squared_error: 6.0954 - binary_crossentropy: -1.3004
#
# Epoch 27/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 5.9736 - mean_squared_error: 5.9736 - binary_crossentropy: -1.7192
#
# Epoch 28/300
# 100/100 [==============================]100/100 [==============================] - 0s 60us/step - loss: 5.8531 - mean_squared_error: 5.8531 - binary_crossentropy: -2.2957
#
# Epoch 29/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 5.7335 - mean_squared_error: 5.7335 - binary_crossentropy: -4.7259
#
# Epoch 30/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 5.6147 - mean_squared_error: 5.6147 - binary_crossentropy: -6.3482
#
# Epoch 31/300
# 100/100 [==============================]100/100 [==============================] - 0s 60us/step - loss: 5.4966 - mean_squared_error: 5.4966 - binary_crossentropy: -9.9984
#
# Epoch 32/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 5.3788 - mean_squared_error: 5.3788 - binary_crossentropy: -12.2051
#
# Epoch 33/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 5.2614 - mean_squared_error: 5.2614 - binary_crossentropy: -14.0766
#
# Epoch 34/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 5.1444 - mean_squared_error: 5.1444 - binary_crossentropy: -15.1080
#
# Epoch 35/300
# 100/100 [==============================]100/100 [==============================] - 0s 70us/step - loss: 5.0279 - mean_squared_error: 5.0279 - binary_crossentropy: -16.5890
#
# Epoch 36/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 4.9120 - mean_squared_error: 4.9120 - binary_crossentropy: -19.0510
#
# Epoch 37/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 4.7967 - mean_squared_error: 4.7967 - binary_crossentropy: -20.5335
#
# Epoch 38/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 4.6825 - mean_squared_error: 4.6825 - binary_crossentropy: -21.4258
#
# Epoch 39/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 4.5695 - mean_squared_error: 4.5695 - binary_crossentropy: -22.3397
# Epoch 40/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 4.4579 - mean_squared_error: 4.4579 - binary_crossentropy: -22.7001
#
# Epoch 41/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 4.3480 - mean_squared_error: 4.3480 - binary_crossentropy: -23.2557
#
# Epoch 42/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 4.2388 - mean_squared_error: 4.2388 - binary_crossentropy: -23.4036
#
# Epoch 43/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 4.1302 - mean_squared_error: 4.1302 - binary_crossentropy: -23.8709
#
# Epoch 44/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 4.0222 - mean_squared_error: 4.0222 - binary_crossentropy: -24.3209
#
# Epoch 45/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 3.9139 - mean_squared_error: 3.9139 - binary_crossentropy: -24.4012
#
# Epoch 46/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 3.8076 - mean_squared_error: 3.8076 - binary_crossentropy: -24.8329
#
# Epoch 47/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 3.7020 - mean_squared_error: 3.7020 - binary_crossentropy: -25.2058
#
# Epoch 48/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 3.5963 - mean_squared_error: 3.5963 - binary_crossentropy: -25.4238
#
# Epoch 49/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 3.4926 - mean_squared_error: 3.4926 - binary_crossentropy: -25.6108
#
# Epoch 50/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 3.3901 - mean_squared_error: 3.3901 - binary_crossentropy: -25.6969
#
# Epoch 51/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 3.2885 - mean_squared_error: 3.2885 - binary_crossentropy: -26.1025
#
# Epoch 52/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 3.1880 - mean_squared_error: 3.1880 - binary_crossentropy: -26.2872
#
# Epoch 53/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 3.0885 - mean_squared_error: 3.0885 - binary_crossentropy: -26.7443
#
# Epoch 54/300
# 100/100 [==============================]100/100 [==============================] - 0s 60us/step - loss: 2.9901 - mean_squared_error: 2.9901 - binary_crossentropy: -26.9177
#
# Epoch 55/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 2.8927 - mean_squared_error: 2.8927 - binary_crossentropy: -27.6695
#
# Epoch 56/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 2.7964 - mean_squared_error: 2.7964 - binary_crossentropy: -27.6859
#
# Epoch 57/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 2.7012 - mean_squared_error: 2.7012 - binary_crossentropy: -27.7747
#
# Epoch 58/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 2.6073 - mean_squared_error: 2.6073 - binary_crossentropy: -27.9015
#
# Epoch 59/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 2.5147 - mean_squared_error: 2.5147 - binary_crossentropy: -27.9634
#
# Epoch 60/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 2.4236 - mean_squared_error: 2.4236 - binary_crossentropy: -28.0092
#
# Epoch 61/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 2.3338 - mean_squared_error: 2.3338 - binary_crossentropy: -28.0470
#
# Epoch 62/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 2.2456 - mean_squared_error: 2.2456 - binary_crossentropy: -28.0492
#
# Epoch 63/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 2.1590 - mean_squared_error: 2.1590 - binary_crossentropy: -28.0954
#
# Epoch 64/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 2.0739 - mean_squared_error: 2.0739 - binary_crossentropy: -28.0931
#
# Epoch 65/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 1.9906 - mean_squared_error: 1.9906 - binary_crossentropy: -28.0907
#
# Epoch 66/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 1.9089 - mean_squared_error: 1.9089 - binary_crossentropy: -28.0940
#
# Epoch 67/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 1.8291 - mean_squared_error: 1.8291 - binary_crossentropy: -28.0892
#
# Epoch 68/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 1.7511 - mean_squared_error: 1.7511 - binary_crossentropy: -28.0810
#
# Epoch 69/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 1.6751 - mean_squared_error: 1.6751 - binary_crossentropy: -28.0743
#
# Epoch 70/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 1.6010 - mean_squared_error: 1.6010 - binary_crossentropy: -28.0519
#
# Epoch 71/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 1.5289 - mean_squared_error: 1.5289 - binary_crossentropy: -28.0432
#
# Epoch 72/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 1.4589 - mean_squared_error: 1.4589 - binary_crossentropy: -28.0065
#
# Epoch 73/300
# 100/100 [==============================]100/100 [==============================] - 0s 60us/step - loss: 1.3910 - mean_squared_error: 1.3910 - binary_crossentropy: -27.9948
#
# Epoch 74/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 1.3252 - mean_squared_error: 1.3252 - binary_crossentropy: -27.9451
#
# Epoch 75/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 1.2615 - mean_squared_error: 1.2615 - binary_crossentropy: -27.8978
#
# Epoch 76/300
# 100/100 [==============================]100/100 [==============================] - 0s 70us/step - loss: 1.2001 - mean_squared_error: 1.2001 - binary_crossentropy: -27.8823
#
# Epoch 77/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 1.1405 - mean_squared_error: 1.1405 - binary_crossentropy: -27.8555
#
# Epoch 78/300
# 100/100 [==============================]100/100 [==============================] - 0s 60us/step - loss: 1.0835 - mean_squared_error: 1.0835 - binary_crossentropy: -27.6848
#
# Epoch 79/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 1.0288 - mean_squared_error: 1.0288 - binary_crossentropy: -27.6116
#
# Epoch 80/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.9763 - mean_squared_error: 0.9763 - binary_crossentropy: -27.5369
#
# Epoch 81/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.9261 - mean_squared_error: 0.9261 - binary_crossentropy: -27.3881
#
# Epoch 82/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.8782 - mean_squared_error: 0.8782 - binary_crossentropy: -27.2632
#
# Epoch 83/300
# 100/100 [==============================]100/100 [==============================] - 0s 60us/step - loss: 0.8325 - mean_squared_error: 0.8325 - binary_crossentropy: -27.1894
#
# Epoch 84/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.7891 - mean_squared_error: 0.7891 - binary_crossentropy: -27.1870
# Epoch 85/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.7479 - mean_squared_error: 0.7479 - binary_crossentropy: -27.1834
#
# Epoch 86/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.7090 - mean_squared_error: 0.7090 - binary_crossentropy: -27.1761
#
# Epoch 87/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.6720 - mean_squared_error: 0.6720 - binary_crossentropy: -27.0930
#
# Epoch 88/300
# 100/100 [==============================]100/100 [==============================] - 0s 60us/step - loss: 0.6374 - mean_squared_error: 0.6374 - binary_crossentropy: -27.0930
#
# Epoch 89/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.6049 - mean_squared_error: 0.6049 - binary_crossentropy: -27.0930
#
# Epoch 90/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.5745 - mean_squared_error: 0.5745 - binary_crossentropy: -27.0930
#
# Epoch 91/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.5461 - mean_squared_error: 0.5461 - binary_crossentropy: -27.0930
#
# Epoch 92/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.5196 - mean_squared_error: 0.5196 - binary_crossentropy: -27.0930
#
# Epoch 93/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.4950 - mean_squared_error: 0.4950 - binary_crossentropy: -27.0930
#
# Epoch 94/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.4723 - mean_squared_error: 0.4723 - binary_crossentropy: -27.0930
#
# Epoch 95/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.4513 - mean_squared_error: 0.4513 - binary_crossentropy: -27.0930
#
# Epoch 96/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.4320 - mean_squared_error: 0.4320 - binary_crossentropy: -27.0930
#
# Epoch 97/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.4143 - mean_squared_error: 0.4143 - binary_crossentropy: -27.0930
#
# Epoch 98/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.3981 - mean_squared_error: 0.3981 - binary_crossentropy: -27.0930
#
# Epoch 99/300
# 100/100 [==============================]100/100 [==============================] - 0s 60us/step - loss: 0.3834 - mean_squared_error: 0.3834 - binary_crossentropy: -27.0930
#
# Epoch 100/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.3700 - mean_squared_error: 0.3700 - binary_crossentropy: -27.0930
#
# Epoch 101/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.3580 - mean_squared_error: 0.3580 - binary_crossentropy: -27.0930
#
# Epoch 102/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.3470 - mean_squared_error: 0.3470 - binary_crossentropy: -27.0930
#
# Epoch 103/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.3372 - mean_squared_error: 0.3372 - binary_crossentropy: -27.0930
#
# Epoch 104/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.3283 - mean_squared_error: 0.3283 - binary_crossentropy: -27.0930
#
# Epoch 105/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.3204 - mean_squared_error: 0.3204 - binary_crossentropy: -27.0930
#
# Epoch 106/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.3134 - mean_squared_error: 0.3134 - binary_crossentropy: -27.0930
#
# Epoch 107/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.3071 - mean_squared_error: 0.3071 - binary_crossentropy: -27.0930
#
# Epoch 108/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.3015 - mean_squared_error: 0.3015 - binary_crossentropy: -27.0930
#
# Epoch 109/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.2965 - mean_squared_error: 0.2965 - binary_crossentropy: -27.0930
#
# Epoch 110/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.2921 - mean_squared_error: 0.2921 - binary_crossentropy: -27.0930
#
# Epoch 111/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.2882 - mean_squared_error: 0.2882 - binary_crossentropy: -27.0930
#
# Epoch 112/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.2847 - mean_squared_error: 0.2847 - binary_crossentropy: -27.0930
#
# Epoch 113/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.2816 - mean_squared_error: 0.2816 - binary_crossentropy: -27.0930
#
# Epoch 114/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.2788 - mean_squared_error: 0.2788 - binary_crossentropy: -27.0930
#
# Epoch 115/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.2763 - mean_squared_error: 0.2763 - binary_crossentropy: -27.0930
#
# Epoch 116/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.2740 - mean_squared_error: 0.2740 - binary_crossentropy: -27.0930
#
# Epoch 117/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.2719 - mean_squared_error: 0.2719 - binary_crossentropy: -27.0930
#
# Epoch 118/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.2700 - mean_squared_error: 0.2700 - binary_crossentropy: -27.0930
#
# Epoch 119/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.2682 - mean_squared_error: 0.2682 - binary_crossentropy: -27.0930
#
# Epoch 120/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.2665 - mean_squared_error: 0.2665 - binary_crossentropy: -27.0930
#
# Epoch 121/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.2648 - mean_squared_error: 0.2648 - binary_crossentropy: -27.0930
#
# Epoch 122/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.2633 - mean_squared_error: 0.2633 - binary_crossentropy: -27.0930
#
# Epoch 123/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.2617 - mean_squared_error: 0.2617 - binary_crossentropy: -27.0930
#
# Epoch 124/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.2602 - mean_squared_error: 0.2602 - binary_crossentropy: -27.0930
#
# Epoch 125/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.2587 - mean_squared_error: 0.2587 - binary_crossentropy: -27.0930
#
# Epoch 126/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.2572 - mean_squared_error: 0.2572 - binary_crossentropy: -27.0930
#
# Epoch 127/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.2557 - mean_squared_error: 0.2557 - binary_crossentropy: -27.0930
#
# Epoch 128/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.2541 - mean_squared_error: 0.2541 - binary_crossentropy: -27.0930
# Epoch 129/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.2526 - mean_squared_error: 0.2526 - binary_crossentropy: -27.0930
#
# Epoch 130/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.2510 - mean_squared_error: 0.2510 - binary_crossentropy: -27.0930
#
# Epoch 131/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.2495 - mean_squared_error: 0.2495 - binary_crossentropy: -27.0930
#
# Epoch 132/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.2479 - mean_squared_error: 0.2479 - binary_crossentropy: -27.0930
#
# Epoch 133/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.2463 - mean_squared_error: 0.2463 - binary_crossentropy: -27.0930
#
# Epoch 134/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.2447 - mean_squared_error: 0.2447 - binary_crossentropy: -27.0930
#
# Epoch 135/300
# 100/100 [==============================]100/100 [==============================] - 0s 70us/step - loss: 0.2430 - mean_squared_error: 0.2430 - binary_crossentropy: -27.0930
#
# Epoch 136/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.2414 - mean_squared_error: 0.2414 - binary_crossentropy: -27.0930
#
# Epoch 137/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.2398 - mean_squared_error: 0.2398 - binary_crossentropy: -27.0930
#
# Epoch 138/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.2381 - mean_squared_error: 0.2381 - binary_crossentropy: -27.0930
#
# Epoch 139/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.2365 - mean_squared_error: 0.2365 - binary_crossentropy: -27.0930
#
# Epoch 140/300
# 100/100 [==============================]100/100 [==============================] - 0s 60us/step - loss: 0.2348 - mean_squared_error: 0.2348 - binary_crossentropy: -27.0930
#
# Epoch 141/300
# 100/100 [==============================]100/100 [==============================] - 0s 60us/step - loss: 0.2331 - mean_squared_error: 0.2331 - binary_crossentropy: -27.0930
#
# Epoch 142/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.2315 - mean_squared_error: 0.2315 - binary_crossentropy: -27.0930
#
# Epoch 143/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.2298 - mean_squared_error: 0.2298 - binary_crossentropy: -27.0930
#
# Epoch 144/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.2281 - mean_squared_error: 0.2281 - binary_crossentropy: -27.0930
#
# Epoch 145/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.2265 - mean_squared_error: 0.2265 - binary_crossentropy: -27.0930
#
# Epoch 146/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.2248 - mean_squared_error: 0.2248 - binary_crossentropy: -27.0930
#
# Epoch 147/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.2232 - mean_squared_error: 0.2232 - binary_crossentropy: -27.0930
#
# Epoch 148/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.2215 - mean_squared_error: 0.2215 - binary_crossentropy: -27.0930
#
# Epoch 149/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.2199 - mean_squared_error: 0.2199 - binary_crossentropy: -27.0930
#
# Epoch 150/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.2183 - mean_squared_error: 0.2183 - binary_crossentropy: -27.0930
#
# Epoch 151/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.2167 - mean_squared_error: 0.2167 - binary_crossentropy: -27.0930
#
# Epoch 152/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.2151 - mean_squared_error: 0.2151 - binary_crossentropy: -27.0930
#
# Epoch 153/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.2135 - mean_squared_error: 0.2135 - binary_crossentropy: -27.0930
#
# Epoch 154/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.2119 - mean_squared_error: 0.2119 - binary_crossentropy: -27.0930
#
# Epoch 155/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.2103 - mean_squared_error: 0.2103 - binary_crossentropy: -27.0930
#
# Epoch 156/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.2087 - mean_squared_error: 0.2087 - binary_crossentropy: -27.0930
#
# Epoch 157/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.2071 - mean_squared_error: 0.2071 - binary_crossentropy: -27.0930
#
# Epoch 158/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.2056 - mean_squared_error: 0.2056 - binary_crossentropy: -27.0930
#
# Epoch 159/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.2040 - mean_squared_error: 0.2040 - binary_crossentropy: -27.0930
#
# Epoch 160/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.2024 - mean_squared_error: 0.2024 - binary_crossentropy: -27.0930
#
# Epoch 161/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.2009 - mean_squared_error: 0.2009 - binary_crossentropy: -27.0930
#
# Epoch 162/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.1994 - mean_squared_error: 0.1994 - binary_crossentropy: -27.0930
#
# Epoch 163/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1978 - mean_squared_error: 0.1978 - binary_crossentropy: -27.0930
#
# Epoch 164/300
# 100/100 [==============================]100/100 [==============================] - 0s 70us/step - loss: 0.1963 - mean_squared_error: 0.1963 - binary_crossentropy: -27.0930
#
# Epoch 165/300
# 100/100 [==============================]100/100 [==============================] - 0s 60us/step - loss: 0.1948 - mean_squared_error: 0.1948 - binary_crossentropy: -27.0930
#
# Epoch 166/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.1933 - mean_squared_error: 0.1933 - binary_crossentropy: -27.0930
#
# Epoch 167/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.1917 - mean_squared_error: 0.1917 - binary_crossentropy: -27.0930
#
# Epoch 168/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.1902 - mean_squared_error: 0.1902 - binary_crossentropy: -27.0930
#
# Epoch 169/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1887 - mean_squared_error: 0.1887 - binary_crossentropy: -27.0930
#
# Epoch 170/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.1872 - mean_squared_error: 0.1872 - binary_crossentropy: -27.0930
#
# Epoch 171/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.1857 - mean_squared_error: 0.1857 - binary_crossentropy: -27.0930
#
# Epoch 172/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1842 - mean_squared_error: 0.1842 - binary_crossentropy: -27.0930
# Epoch 173/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.1827 - mean_squared_error: 0.1827 - binary_crossentropy: -27.0930
#
# Epoch 174/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.1813 - mean_squared_error: 0.1813 - binary_crossentropy: -27.0930
#
# Epoch 175/300
# 100/100 [==============================]100/100 [==============================] - 0s 41us/step - loss: 0.1798 - mean_squared_error: 0.1798 - binary_crossentropy: -27.0930
#
# Epoch 176/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.1783 - mean_squared_error: 0.1783 - binary_crossentropy: -27.0930
#
# Epoch 177/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1768 - mean_squared_error: 0.1768 - binary_crossentropy: -27.0930
#
# Epoch 178/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.1754 - mean_squared_error: 0.1754 - binary_crossentropy: -27.0930
#
# Epoch 179/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.1739 - mean_squared_error: 0.1739 - binary_crossentropy: -27.0930
#
# Epoch 180/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.1724 - mean_squared_error: 0.1724 - binary_crossentropy: -27.0930
#
# Epoch 181/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.1710 - mean_squared_error: 0.1710 - binary_crossentropy: -27.0930
#
# Epoch 182/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.1695 - mean_squared_error: 0.1695 - binary_crossentropy: -27.0930
#
# Epoch 183/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.1681 - mean_squared_error: 0.1681 - binary_crossentropy: -27.0930
#
# Epoch 184/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1667 - mean_squared_error: 0.1667 - binary_crossentropy: -27.0930
#
# Epoch 185/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.1652 - mean_squared_error: 0.1652 - binary_crossentropy: -27.0930
#
# Epoch 186/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.1638 - mean_squared_error: 0.1638 - binary_crossentropy: -27.0930
#
# Epoch 187/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1623 - mean_squared_error: 0.1623 - binary_crossentropy: -27.0930
#
# Epoch 188/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1609 - mean_squared_error: 0.1609 - binary_crossentropy: -27.0930
#
# Epoch 189/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1595 - mean_squared_error: 0.1595 - binary_crossentropy: -27.0930
#
# Epoch 190/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.1581 - mean_squared_error: 0.1581 - binary_crossentropy: -27.0930
#
# Epoch 191/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.1567 - mean_squared_error: 0.1567 - binary_crossentropy: -27.0930
#
# Epoch 192/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.1553 - mean_squared_error: 0.1553 - binary_crossentropy: -27.0930
#
# Epoch 193/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1539 - mean_squared_error: 0.1539 - binary_crossentropy: -27.0930
#
# Epoch 194/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.1525 - mean_squared_error: 0.1525 - binary_crossentropy: -27.0930
#
# Epoch 195/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.1511 - mean_squared_error: 0.1511 - binary_crossentropy: -27.0930
#
# Epoch 196/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1497 - mean_squared_error: 0.1497 - binary_crossentropy: -27.0930
#
# Epoch 197/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1483 - mean_squared_error: 0.1483 - binary_crossentropy: -27.0930
#
# Epoch 198/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1470 - mean_squared_error: 0.1470 - binary_crossentropy: -27.0930
#
# Epoch 199/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.1456 - mean_squared_error: 0.1456 - binary_crossentropy: -27.1545
#
# Epoch 200/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.1442 - mean_squared_error: 0.1442 - binary_crossentropy: -27.1699
#
# Epoch 201/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1429 - mean_squared_error: 0.1429 - binary_crossentropy: -27.1745
#
# Epoch 202/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1415 - mean_squared_error: 0.1415 - binary_crossentropy: -27.1773
#
# Epoch 203/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1402 - mean_squared_error: 0.1402 - binary_crossentropy: -27.1794
#
# Epoch 204/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1388 - mean_squared_error: 0.1388 - binary_crossentropy: -27.1810
#
# Epoch 205/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1375 - mean_squared_error: 0.1375 - binary_crossentropy: -27.1824
#
# Epoch 206/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1362 - mean_squared_error: 0.1362 - binary_crossentropy: -27.1835
#
# Epoch 207/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1348 - mean_squared_error: 0.1348 - binary_crossentropy: -27.1845
#
# Epoch 208/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1335 - mean_squared_error: 0.1335 - binary_crossentropy: -27.1854
#
# Epoch 209/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1322 - mean_squared_error: 0.1322 - binary_crossentropy: -27.1861
#
# Epoch 210/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1309 - mean_squared_error: 0.1309 - binary_crossentropy: -27.1868
#
# Epoch 211/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.1296 - mean_squared_error: 0.1296 - binary_crossentropy: -27.1875
#
# Epoch 212/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.1283 - mean_squared_error: 0.1283 - binary_crossentropy: -27.1880
#
# Epoch 213/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.1270 - mean_squared_error: 0.1270 - binary_crossentropy: -27.1886
#
# Epoch 214/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.1257 - mean_squared_error: 0.1257 - binary_crossentropy: -27.1891
#
# Epoch 215/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1245 - mean_squared_error: 0.1245 - binary_crossentropy: -27.1896
#
# Epoch 216/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1232 - mean_squared_error: 0.1232 - binary_crossentropy: -27.1900
# Epoch 217/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.1219 - mean_squared_error: 0.1219 - binary_crossentropy: -27.1904
#
# Epoch 218/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.1207 - mean_squared_error: 0.1207 - binary_crossentropy: -27.1908
#
# Epoch 219/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1194 - mean_squared_error: 0.1194 - binary_crossentropy: -27.1912
#
# Epoch 220/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.1182 - mean_squared_error: 0.1182 - binary_crossentropy: -27.1916
#
# Epoch 221/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1170 - mean_squared_error: 0.1170 - binary_crossentropy: -27.1919
#
# Epoch 222/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.1157 - mean_squared_error: 0.1157 - binary_crossentropy: -27.1922
#
# Epoch 223/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1145 - mean_squared_error: 0.1145 - binary_crossentropy: -27.1925
#
# Epoch 224/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1133 - mean_squared_error: 0.1133 - binary_crossentropy: -27.2497
#
# Epoch 225/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1121 - mean_squared_error: 0.1121 - binary_crossentropy: -27.2592
#
# Epoch 226/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.1109 - mean_squared_error: 0.1109 - binary_crossentropy: -27.2630
#
# Epoch 227/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1097 - mean_squared_error: 0.1097 - binary_crossentropy: -27.2655
#
# Epoch 228/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1085 - mean_squared_error: 0.1085 - binary_crossentropy: -27.2674
#
# Epoch 229/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1073 - mean_squared_error: 0.1073 - binary_crossentropy: -27.2690
#
# Epoch 230/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.1061 - mean_squared_error: 0.1061 - binary_crossentropy: -27.2703
#
# Epoch 231/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.1050 - mean_squared_error: 0.1050 - binary_crossentropy: -27.2714
#
# Epoch 232/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1038 - mean_squared_error: 0.1038 - binary_crossentropy: -27.2725
#
# Epoch 233/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.1026 - mean_squared_error: 0.1026 - binary_crossentropy: -27.2734
#
# Epoch 234/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.1015 - mean_squared_error: 0.1015 - binary_crossentropy: -27.2742
#
# Epoch 235/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.1004 - mean_squared_error: 0.1004 - binary_crossentropy: -27.3700
#
# Epoch 236/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.0992 - mean_squared_error: 0.0992 - binary_crossentropy: -27.3984
#
# Epoch 237/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.0981 - mean_squared_error: 0.0981 - binary_crossentropy: -27.4054
#
# Epoch 238/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.0970 - mean_squared_error: 0.0970 - binary_crossentropy: -27.4101
#
# Epoch 239/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.0959 - mean_squared_error: 0.0959 - binary_crossentropy: -27.4136
#
# Epoch 240/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.0947 - mean_squared_error: 0.0947 - binary_crossentropy: -27.4730
#
# Epoch 241/300
# 100/100 [==============================]100/100 [==============================] - 0s 60us/step - loss: 0.0936 - mean_squared_error: 0.0936 - binary_crossentropy: -27.5189
#
# Epoch 242/300
# 100/100 [==============================]100/100 [==============================] - 0s 60us/step - loss: 0.0926 - mean_squared_error: 0.0926 - binary_crossentropy: -27.5410
#
# Epoch 243/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.0915 - mean_squared_error: 0.0915 - binary_crossentropy: -27.5484
#
# Epoch 244/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.0904 - mean_squared_error: 0.0904 - binary_crossentropy: -27.5536
#
# Epoch 245/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.0893 - mean_squared_error: 0.0893 - binary_crossentropy: -27.5578
#
# Epoch 246/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.0883 - mean_squared_error: 0.0883 - binary_crossentropy: -27.5614
#
# Epoch 247/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.0872 - mean_squared_error: 0.0872 - binary_crossentropy: -27.5645
#
# Epoch 248/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.0861 - mean_squared_error: 0.0861 - binary_crossentropy: -27.5672
#
# Epoch 249/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.0851 - mean_squared_error: 0.0851 - binary_crossentropy: -27.5697
#
# Epoch 250/300
# 100/100 [==============================]100/100 [==============================] - 0s 90us/step - loss: 0.0841 - mean_squared_error: 0.0841 - binary_crossentropy: -27.5719
#
# Epoch 251/300
# 100/100 [==============================]100/100 [==============================] - 0s 60us/step - loss: 0.0830 - mean_squared_error: 0.0830 - binary_crossentropy: -27.6223
#
# Epoch 252/300
# 100/100 [==============================]100/100 [==============================] - 0s 70us/step - loss: 0.0820 - mean_squared_error: 0.0820 - binary_crossentropy: -27.6302
#
# Epoch 253/300
# 100/100 [==============================]100/100 [==============================] - 0s 70us/step - loss: 0.0810 - mean_squared_error: 0.0810 - binary_crossentropy: -27.6347
#
# Epoch 254/300
# 100/100 [==============================]100/100 [==============================] - 0s 60us/step - loss: 0.0800 - mean_squared_error: 0.0800 - binary_crossentropy: -27.6381
#
# Epoch 255/300
# 100/100 [==============================]100/100 [==============================] - 0s 70us/step - loss: 0.0790 - mean_squared_error: 0.0790 - binary_crossentropy: -27.6410
#
# Epoch 256/300
# 100/100 [==============================]100/100 [==============================] - 0s 90us/step - loss: 0.0780 - mean_squared_error: 0.0780 - binary_crossentropy: -27.6436
#
# Epoch 257/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.0770 - mean_squared_error: 0.0770 - binary_crossentropy: -27.6459
#
# Epoch 258/300
# 100/100 [==============================]100/100 [==============================] - 0s 60us/step - loss: 0.0761 - mean_squared_error: 0.0761 - binary_crossentropy: -27.6480
#
# Epoch 259/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.0751 - mean_squared_error: 0.0751 - binary_crossentropy: -27.6971
#
# Epoch 260/300
# 100/100 [==============================]100/100 [==============================] - 0s 70us/step - loss: 0.0741 - mean_squared_error: 0.0741 - binary_crossentropy: -27.7031
# Epoch 261/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.0732 - mean_squared_error: 0.0732 - binary_crossentropy: -27.7070
#
# Epoch 262/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.0722 - mean_squared_error: 0.0722 - binary_crossentropy: -27.7102
#
# Epoch 263/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.0713 - mean_squared_error: 0.0713 - binary_crossentropy: -27.7128
#
# Epoch 264/300
# 100/100 [==============================]100/100 [==============================] - 0s 60us/step - loss: 0.0704 - mean_squared_error: 0.0704 - binary_crossentropy: -27.7152
#
# Epoch 265/300
# 100/100 [==============================]100/100 [==============================] - 0s 70us/step - loss: 0.0694 - mean_squared_error: 0.0694 - binary_crossentropy: -27.7615
#
# Epoch 266/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.0685 - mean_squared_error: 0.0685 - binary_crossentropy: -27.8051
#
# Epoch 267/300
# 100/100 [==============================]100/100 [==============================] - 0s 100us/step - loss: 0.0676 - mean_squared_error: 0.0676 - binary_crossentropy: -27.8632
#
# Epoch 268/300
# 100/100 [==============================]100/100 [==============================] - 0s 70us/step - loss: 0.0667 - mean_squared_error: 0.0667 - binary_crossentropy: -27.8725
#
# Epoch 269/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.0658 - mean_squared_error: 0.0658 - binary_crossentropy: -27.8789
#
# Epoch 270/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.0649 - mean_squared_error: 0.0649 - binary_crossentropy: -27.8839
#
# Epoch 271/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.0641 - mean_squared_error: 0.0641 - binary_crossentropy: -27.8880
#
# Epoch 272/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.0632 - mean_squared_error: 0.0632 - binary_crossentropy: -27.8916
#
# Epoch 273/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.0623 - mean_squared_error: 0.0623 - binary_crossentropy: -27.8948
#
# Epoch 274/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.0615 - mean_squared_error: 0.0615 - binary_crossentropy: -27.8978
#
# Epoch 275/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.0606 - mean_squared_error: 0.0606 - binary_crossentropy: -27.9005
#
# Epoch 276/300
# 100/100 [==============================]100/100 [==============================] - 0s 60us/step - loss: 0.0598 - mean_squared_error: 0.0598 - binary_crossentropy: -27.9029
#
# Epoch 277/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.0589 - mean_squared_error: 0.0589 - binary_crossentropy: -27.9052
#
# Epoch 278/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.0581 - mean_squared_error: 0.0581 - binary_crossentropy: -27.9074
#
# Epoch 279/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.0573 - mean_squared_error: 0.0573 - binary_crossentropy: -27.9094
#
# Epoch 280/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.0565 - mean_squared_error: 0.0565 - binary_crossentropy: -27.9113
#
# Epoch 281/300
# 100/100 [==============================]100/100 [==============================] - 0s 60us/step - loss: 0.0557 - mean_squared_error: 0.0557 - binary_crossentropy: -27.9132
#
# Epoch 282/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.0549 - mean_squared_error: 0.0549 - binary_crossentropy: -27.9149
#
# Epoch 283/300
# 100/100 [==============================]100/100 [==============================] - 0s 80us/step - loss: 0.0541 - mean_squared_error: 0.0541 - binary_crossentropy: -27.9166
#
# Epoch 284/300
# 100/100 [==============================]100/100 [==============================] - 0s 60us/step - loss: 0.0533 - mean_squared_error: 0.0533 - binary_crossentropy: -27.9182
#
# Epoch 285/300
# 100/100 [==============================]100/100 [==============================] - 0s 60us/step - loss: 0.0526 - mean_squared_error: 0.0526 - binary_crossentropy: -27.9197
#
# Epoch 286/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.0518 - mean_squared_error: 0.0518 - binary_crossentropy: -27.9211
#
# Epoch 287/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.0510 - mean_squared_error: 0.0510 - binary_crossentropy: -27.9225
#
# Epoch 288/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.0503 - mean_squared_error: 0.0503 - binary_crossentropy: -27.9239
#
# Epoch 289/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.0496 - mean_squared_error: 0.0496 - binary_crossentropy: -27.9252
#
# Epoch 290/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.0488 - mean_squared_error: 0.0488 - binary_crossentropy: -27.9265
#
# Epoch 291/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.0481 - mean_squared_error: 0.0481 - binary_crossentropy: -27.9277
#
# Epoch 292/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.0474 - mean_squared_error: 0.0474 - binary_crossentropy: -27.9289
#
# Epoch 293/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.0467 - mean_squared_error: 0.0467 - binary_crossentropy: -27.9300
#
# Epoch 294/300
# 100/100 [==============================]100/100 [==============================] - 0s 60us/step - loss: 0.0460 - mean_squared_error: 0.0460 - binary_crossentropy: -27.9311
#
# Epoch 295/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.0453 - mean_squared_error: 0.0453 - binary_crossentropy: -27.9322
#
# Epoch 296/300
# 100/100 [==============================]100/100 [==============================] - 0s 40us/step - loss: 0.0446 - mean_squared_error: 0.0446 - binary_crossentropy: -27.9332
#
# Epoch 297/300
# 100/100 [==============================]100/100 [==============================] - 0s 120us/step - loss: 0.0439 - mean_squared_error: 0.0439 - binary_crossentropy: -27.9342
#
# Epoch 298/300
# 100/100 [==============================]100/100 [==============================] - 0s 30us/step - loss: 0.0432 - mean_squared_error: 0.0432 - binary_crossentropy: -27.9352
#
# Epoch 299/300
# 100/100 [==============================]100/100 [==============================] - 0s 70us/step - loss: 0.0425 - mean_squared_error: 0.0425 - binary_crossentropy: -27.9676
#
# Epoch 300/300
# 100/100 [==============================]100/100 [==============================] - 0s 50us/step - loss: 0.0419 - mean_squared_error: 0.0419 - binary_crossentropy: -27.9718

# %% [markdown]
# # Tensorflow 계산기
# Tensorflow를 이용해 간단한 실수 사칙연산 계산기를 만들어보세요.
#
# 사용되는 모든 기능은 tensorflow 내장 함수를 사용해주세요.
#
# ### 미션
# * tf.add()
# * tf.subtract()
# * tf.multiply()
# * tf.truediv()
#
# insert()함수로 두 실수 x, y와 어떤 연산을 할것인지 정하는 cal(+, -, *, /)을 입력하세요.
#
# calcul() 을 완성시켜보세요.
#
# 모든 기능을 tensorflow 내장 함수로 구현해주세요.

# %%
import tensorflow as tf
import numpy as np

# Main()에서 insert 함수를 호출해서 정수 또는 실수를 입력받으세요.
# 제출할 때는 insert 함수를 주석처리하고 제출하세요.
def insert():
    x = float(input('정수 또는 실수를 입력하세요. x : '))
    y = float(input('정수 또는 실수를 입력하세요. y : '))
    cal = input('어떤 연산을 할것인지 입력하세요. (+, -, *, /)')
    return x, y, cal

# 사칙연산 함수를 구현해보세요.

def calcul(x,y,cal):
    result = 0
    # 더하기
    if cal == '+':
        result = tf.add(x,y)        #tf.Variable((x+y),name='result').numpy()
    # 빼기
    elif cal == '-':
        result =tf.subtract(x,y)        #tf.Variable((x-y),name='result').numpy()
    # 곱하기
    elif cal == '*':
        result = tf.multiply(x,y)               #tf.Variable((x*y),name='result').numpy()
    # 나누기
    elif cal == '/':
        result =tf.truediv(x,y)                   #tf.Variable((x/y),name='result').numpy()
    return result.numpy()

# 제출할 땐 insert를 주석 처리 (#) 하고 제출해주세요.
x, y, cal = insert()

# calcul 함수를 호출해 실수 사칙연산을 수행하고 결과를 출력해보세요.
# 제출할 땐 print를 주석 처리 (#) 하고 제출해주세요.
print(calcul(x,y,cal))
# Out:
# 정수 또는 실수를 입력하세요. x : 6
# 정수 또는 실수를 입력하세요. y : 5
# 어떤 연산을 할것인지 입력하세요. (+, -, *, /)+
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-094c908d3d4e> in <module>()
#      33 # calcul 함수를 호출해 실수 사칙연산을 수행하고 결과를 출력해보세요.
#      34 # 제출할 땐 print를 주석 처리 (#) 하고 제출해주세요.
# ---> 35 print(calcul(x,y,cal))
#      36
#
# <ipython-input-17-094c908d3d4e> in calcul(x, y, cal)
#      26     elif cal == '/':
#      27         result =tf.truediv(x,y)                   #tf.Variable((x/y),name='result').numpy()
# ---> 28     return result.numpy()
#      29
#      30 # 제출할 땐 insert를 주석 처리 (#) 하고 제출해주세요.
#
# AttributeError: 'Tensor' object has no attribute 'numpy'

# %% [markdown]
# # Tensorflow Linear Regression
# 앞서 실습에서 진행한 선형 회귀를 직접 구현해보겠습니다.
#
# 주어진 x_data,y_data 에 대해 hypothesis를 만들고 W와 b를 업데이트 해보세요.
#
# ### 미션
# 학습에 필요한 파라미터를 선언해주세요.
#
# * train_step, learning_rate
#
# hypothesis를 만들어보세요.
#
# cost에 손실 함수를 설계해보세요.
#
# Line 44, 45 에서 W와 b를 업데이트해주세요.
#
# W, b의 오차 범위가 -0.3 ~ +0.3 가 되도록 학습시켜 보세요.

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

def Visualize(x_data, y_data, hypothesis):
    fig, ax = plt.subplots()
    ax.grid()
    ax.plot(x_data, hypothesis.numpy(), 'r-')
    ax.plot(x_data, y_data, 'o')
#     fig.savefig("plot.png")

# Hyperparameter 설정
## TODO 1:학습에 필요한 파라미터를 선언합니다.
train_step = 300
learning_rate = 0.01

# 학습에 사용할 데이터입니다.
seed = tf.compat.v1.set_random_seed(40)
x_data = 2 * tf.random.normal([100,1], dtype=tf.float32, seed=seed)
y_data = 3 * x_data + 2 * tf.random.normal([100,1], dtype=tf.float32, seed=seed)

# 학습에 사용될 Weight와 Bias를 선언합니다.
# 일반적으로 랜덤 값으로 선언해 사용하며 학습 데이터와 Shape을 일치시킵니다.
W = tf.Variable((-5.0), dtype=tf.float32)
b = tf.Variable((2.0), dtype=tf.float32)

# 학습을 진행합니다.
for i in range(train_step):
    with tf.GradientTape() as tape:
        # y = W*X + b 형태의 hypothesis를 선언합니다.
        ## TODO 2: hypothesis를 만들어주세요.
        hypothesis = tf.add(W * x_data, b)
        # 에러를 최소화시키는 손실 함수 cost function을 설계합니다.
        ## TODO 3: Cost Function을 설계해주세요. Hint : MSE
        cost = tf.reduce_mean(tf.square(hypothesis - y_data))
    
    # Gradient Descent 방법으로 Error를 최소화하고 Weight와 Bias를 업데이트 합니다.
    W_grad, b_grad = tape.gradient(cost, [W, b])
    
    # TODO 4: Weight와 Bias를 업데이트 해주세요. Hint : Learning_rate * Update Value
    W.assign_sub(learning_rate *W_grad)
    b.assign_sub(learning_rate *b_grad)
    
    # 30번 마다 출력
    if i % 30 == 0:
        Visualize(x_data,y_data,hypothesis)        
        print("Iter : {}| Weight : {:.4f}| Bias : {:.4f}|Cost : {:.4f}".format(i, W.numpy(), b.numpy(), cost))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-fcdd6372feb8> in <module>()
#      16
#      17 # 학습에 사용할 데이터입니다.
# ---> 18 seed = tf.compat.v1.set_random_seed(40)
#      19 x_data = 2 * tf.random.normal([100,1], dtype=tf.float32, seed=seed)
#      20 y_data = 3 * x_data + 2 * tf.random.normal([100,1], dtype=tf.float32, seed=seed)
#
# AttributeError: module 'tensorflow.python.util.compat' has no attribute 'v1'
